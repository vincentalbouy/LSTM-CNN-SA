# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'a', 'anarchism', 'as', 'of', 'originated', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.377485
# Nearest to is: denoting, rescuers, cam, equip, lubricant, energetic, utub, trusteeship,
# Nearest to than: narratives, knocks, misty, dunham, am, debrecen, xxx, clyde,
# Nearest to zero: giuliano, jpl, cities, millar, cdf, nicholas, psych, stung,
# Nearest to war: nanotechnology, agglutinative, init, mia, dreyfus, embittered, haworth, vinyl,
# Nearest to an: dillon, familial, friend, drilling, finish, nonlinear, bitten, typified,
# Nearest to he: randle, rochelle, fergus, ka, haj, uncut, disappointed, thoroughbreds,
# Nearest to state: bara, distress, superfund, ethelbert, falcone, often, honda, kirkwood,
# Nearest to at: parsecs, minivan, metamorphism, vinny, reintegrated, usk, representationalism, hyperfocal,
# Nearest to the: arnulf, tarleton, along, strom, hairstyle, standpoint, cloudbusting, milgrom,
# Nearest to can: sharpe, crawford, warehouse, flatten, recreation, mw, burrow, dianetic,
# Nearest to as: jiang, advisable, kidnappings, wielding, nephew, isaak, brahmic, ishi,
# Nearest to states: licks, kinases, hold, approximately, tur, blackbird, washington, nmi,
# Nearest to many: kune, dependent, motorway, bony, vale, regency, garnered, settle,
# Nearest to four: metternich, explorers, grammatical, netted, subnational, martialed, served, deceit,
# Nearest to not: volkswagen, spitting, satirical, weekly, istria, morea, mallory, gimmicks,
# Nearest to UNK: bundled, bouchard, prohibits, abolishing, descend, malay, wyman, provisional,
# Average loss at step 2000: 4.367203
# Average loss at step 4000: 3.864430
# Average loss at step 6000: 3.787706
# Average loss at step 8000: 3.693304
# Average loss at step 10000: 3.612086
# Nearest to is: was, are, has, be, stockpiling, funneled, sinai, hugh,
# Nearest to than: dunham, knocks, narratives, correspondingly, boxes, disproportionately, or, whale,
# Nearest to zero: seven, eight, five, nine, six, three, four, two,
# Nearest to war: surinam, cur, entry, polo, oxidation, scout, katha, terrific,
# Nearest to an: the, sabbatical, petra, hera, typified, rabbis, locust, congenial,
# Nearest to he: it, she, who, they, there, uncut, fergus, not,
# Nearest to state: kirkwood, falcone, tsarina, junta, zimmerman, superfund, jud, ethelbert,
# Nearest to at: in, on, castes, reprise, actively, after, vinny, summarizing,
# Nearest to the: this, a, his, its, their, an, screenshots, baltic,
# Nearest to can: would, may, tritium, counselor, could, protects, daime, sharpe,
# Nearest to as: destroy, jehovah, by, rufus, avenge, vga, nephew, ishi,
# Nearest to states: hold, electrical, kinases, hertfordshire, appalachians, particularity, blackbird, licks,
# Nearest to many: some, these, dependent, java, signer, settle, families, sock,
# Nearest to four: three, eight, six, seven, five, two, nine, zero,
# Nearest to not: they, it, also, still, parable, who, we, morea,
# Nearest to UNK: waves, hashing, deep, destination, agave, mastiff, coolest, tents,
# Average loss at step 12000: 3.608663
# Average loss at step 14000: 3.573170
# Average loss at step 16000: 3.410167
# Average loss at step 18000: 3.453809
# Average loss at step 20000: 3.545336
# Nearest to is: was, are, has, but, were, be, nucleation, equity,
# Nearest to than: or, disproportionately, dunham, boxes, uneconomic, austere, correspondingly, whale,
# Nearest to zero: five, six, three, seven, four, nine, eight, two,
# Nearest to war: cur, nanotechnology, surinam, terrific, proclaim, miniszt, second, entry,
# Nearest to an: sabbatical, typified, environmentalist, lament, petra, the, locust, delimitation,
# Nearest to he: it, she, who, they, there, fergus, uncut, fletcher,
# Nearest to state: kirkwood, falcone, ethelbert, interpret, surpassed, jud, vitreous, tsarina,
# Nearest to at: in, on, jubilee, coventry, and, from, conjugations, moyne,
# Nearest to the: their, its, his, this, a, withholding, any, an,
# Nearest to can: may, would, could, should, will, daime, must, counselor,
# Nearest to as: paving, supercomputing, specific, imre, isaak, destroy, ko, very,
# Nearest to states: electrical, kingdom, hertfordshire, eesti, begins, appalachians, kinases, particularity,
# Nearest to many: some, several, these, other, all, java, their, dependent,
# Nearest to four: eight, six, three, five, seven, nine, two, zero,
# Nearest to not: they, it, also, still, who, parable, to, never,
# Nearest to UNK: libretto, contravariant, h, alfons, l, aperture, comic, maginot,
# Average loss at step 22000: 3.503883
# Average loss at step 24000: 3.485506
# Average loss at step 26000: 3.483389
# Average loss at step 28000: 3.479720
# Average loss at step 30000: 3.501191
# Nearest to is: was, has, are, became, be, being, stands, were,
# Nearest to than: or, but, disproportionately, austere, purposeful, boxes, dunham, elohim,
# Nearest to zero: five, eight, three, four, six, nine, seven, two,
# Nearest to war: cur, terrific, surinam, beaconsfield, miniszt, nanotechnology, crossed, ravalomanana,
# Nearest to an: locust, sabbatical, pacification, physicians, petra, heapsort, familial, delimitation,
# Nearest to he: she, it, they, who, there, fergus, uncut, never,
# Nearest to state: kirkwood, government, falcone, interpret, surpassed, jud, ethelbert, forces,
# Nearest to at: in, on, during, summarizing, jubilee, after, under, collects,
# Nearest to the: their, its, his, a, faulkner, encased, our, unprepared,
# Nearest to can: may, would, could, will, should, must, cannot, to,
# Nearest to as: supercomputing, septimius, by, gabonese, tsarevich, dhcp, scarp, became,
# Nearest to states: kingdom, begins, specialised, approve, kinases, outlets, hertfordshire, electrical,
# Nearest to many: some, several, these, various, other, most, both, all,
# Nearest to four: five, six, three, eight, seven, two, nine, zero,
# Nearest to not: they, lyapunov, morea, still, to, it, sundry, often,
# Nearest to UNK: de, brezhnev, h, dcc, coolest, l, carboxyl, aeroplane,
# Average loss at step 32000: 3.502215
# Average loss at step 34000: 3.496145
# Average loss at step 36000: 3.451478
# Average loss at step 38000: 3.304191
# Average loss at step 40000: 3.429439
# Nearest to is: was, are, has, be, ellison, became, rearrangement, dystrophy,
# Nearest to than: or, austere, much, elohim, dunham, disproportionately, counselor, purposeful,
# Nearest to zero: seven, five, nine, eight, six, four, three, isidore,
# Nearest to war: cur, former, beaconsfield, crossed, terrific, miniszt, payloads, moltke,
# Nearest to an: pacification, petra, sabbatical, another, heapsort, delimitation, cowboy, typified,
# Nearest to he: she, it, they, who, there, i, finally, we,
# Nearest to state: government, kirkwood, ethelbert, falcone, interpret, jud, president, states,
# Nearest to at: on, in, during, rebuilt, summarizing, under, literally, against,
# Nearest to the: a, their, its, any, this, each, his, another,
# Nearest to can: may, will, could, would, should, must, might, cannot,
# Nearest to as: supercomputing, tz, destroy, tsarevich, when, antiderivative, by, cygnus,
# Nearest to states: kingdom, begins, hertfordshire, outlets, specialised, state, christians, cernan,
# Nearest to many: some, several, these, both, various, those, most, all,
# Nearest to four: six, three, five, seven, eight, two, nine, one,
# Nearest to not: they, it, still, never, also, sundry, often, to,
# Nearest to UNK: b, specificity, d, polyphyletic, ah, roms, johnson, highs,
# Average loss at step 42000: 3.436706
# Average loss at step 44000: 3.449473
# Average loss at step 46000: 3.452145
# Average loss at step 48000: 3.355177
# Average loss at step 50000: 3.383061
# Nearest to is: was, are, has, became, seems, does, aronson, be,
# Nearest to than: or, but, dunham, disproportionately, elohim, much, purposeful, spires,
# Nearest to zero: six, five, seven, eight, four, nine, three, two,
# Nearest to war: former, cur, beaconsfield, kabul, crossed, terrific, surinam, signed,
# Nearest to an: pacification, another, sabbatical, delimitation, sided, cordoba, heapsort, the,
# Nearest to he: she, it, they, who, there, eventually, russell, soon,
# Nearest to state: government, falcone, kirkwood, ethelbert, forces, discredit, interpret, city,
# Nearest to at: during, in, on, explosive, imre, stipend, under, pcbs,
# Nearest to the: its, this, their, a, his, some, any, rawls,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to as: when, brahmic, dhcp, supercomputing, paving, longitudes, desu, advancements,
# Nearest to states: kingdom, hertfordshire, cricketing, begins, outlets, spade, tero, approve,
# Nearest to many: some, several, these, both, various, those, all, such,
# Nearest to four: six, five, seven, three, two, eight, nine, zero,
# Nearest to not: now, sundry, never, lyapunov, still, almost, also, often,
# Nearest to UNK: de, camilo, laughton, lippincott, harsher, bcg, highs, electrified,
# Average loss at step 52000: 3.432534
# Average loss at step 54000: 3.424339
# Average loss at step 56000: 3.436790
# Average loss at step 58000: 3.397037
# Average loss at step 60000: 3.388743
# Nearest to is: was, are, has, became, be, ellison, seems, but,
# Nearest to than: or, but, and, disproportionately, austere, dunham, much, slightly,
# Nearest to zero: five, four, eight, six, seven, nine, three, million,
# Nearest to war: kabul, gravis, crossed, signed, beaconsfield, reluctance, former, lorenzo,
# Nearest to an: delimitation, pacification, sabbatical, familial, cowboy, heapsort, another, petra,
# Nearest to he: she, it, they, there, who, officially, russell, finally,
# Nearest to state: government, falcone, states, city, kirkwood, ethelbert, interpret, hertfordshire,
# Nearest to at: in, displeased, lawrence, lethbridge, during, pcbs, effendi, under,
# Nearest to the: its, a, their, screenshots, his, some, any, this,
# Nearest to can: may, could, would, will, must, might, should, cannot,
# Nearest to as: tsarevich, when, septimius, desu, became, antiderivative, spend, like,
# Nearest to states: kingdom, countries, state, outlets, nations, canada, hertfordshire, approve,
# Nearest to many: some, several, various, these, both, all, other, most,
# Nearest to four: six, five, three, seven, eight, nine, two, zero,
# Nearest to not: now, still, you, never, they, sundry, lyapunov, cfa,
# Nearest to UNK: lyric, prohibits, hog, mahabharata, enforcement, ligand, retrofitted, och,
# Average loss at step 62000: 3.235185
# Average loss at step 64000: 3.249479
# Average loss at step 66000: 3.404182
# Average loss at step 68000: 3.400487
# Average loss at step 70000: 3.360529
# Nearest to is: was, has, are, be, seems, makes, does, became,
# Nearest to than: or, disproportionately, but, slightly, dunham, and, austere, elohim,
# Nearest to zero: five, eight, six, four, nine, seven, three, million,
# Nearest to war: gravis, former, signed, crossed, kabul, cia, beaconsfield, reluctance,
# Nearest to an: the, another, delimitation, sabbatical, pacification, wes, familial, ornamented,
# Nearest to he: she, it, they, who, finally, there, officially, eventually,
# Nearest to state: government, states, city, community, prat, ethelbert, falcone, hertfordshire,
# Nearest to at: klaip, during, shalmaneser, rko, conservatives, summarizing, under, after,
# Nearest to the: its, their, this, a, these, any, another, withholding,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to as: like, when, septimius, tsarevich, straddling, get, antiderivative, cocaine,
# Nearest to states: kingdom, state, countries, nations, hertfordshire, outlets, begins, christians,
# Nearest to many: some, several, these, various, both, all, most, numerous,
# Nearest to four: six, five, seven, three, eight, nine, zero, two,
# Nearest to not: now, never, still, also, generally, lyapunov, they, almost,
# Nearest to UNK: http, bcg, bladed, compatibility, javan, licht, gol, protective,
# Average loss at step 72000: 3.371660
# Average loss at step 74000: 3.350474
# Average loss at step 76000: 3.314854
# Average loss at step 78000: 3.352649
# Average loss at step 80000: 3.378128
# Nearest to is: was, has, are, became, does, be, seems, commence,
# Nearest to than: or, disproportionately, but, much, slightly, and, dunham, purposeful,
# Nearest to zero: five, six, seven, eight, four, nine, three, million,
# Nearest to war: wars, kabul, former, signed, gravis, surinam, stimuli, crossed,
# Nearest to an: delimitation, pacification, petra, familial, sabbatical, another, wes, suicides,
# Nearest to he: she, it, they, there, who, discreet, ahern, finally,
# Nearest to state: government, states, city, community, falcone, ingredient, soloists, prat,
# Nearest to at: in, after, during, summarizing, under, lethbridge, pcbs, without,
# Nearest to the: its, their, this, a, his, each, faulkner, screenshots,
# Nearest to can: could, may, will, would, must, should, might, cannot,
# Nearest to as: ho, septimius, tsarevich, becomes, like, tz, when, driscoll,
# Nearest to states: kingdom, state, countries, nations, hertfordshire, outlets, approve, cricketing,
# Nearest to many: some, several, various, these, most, both, numerous, all,
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Nearest to not: still, now, never, generally, usually, often, we, they,
# Nearest to UNK: lippincott, et, tents, nacional, zamenhof, tra, smith, der,
# Average loss at step 82000: 3.410483
# Average loss at step 84000: 3.412250
# Average loss at step 86000: 3.390248
# Average loss at step 88000: 3.352451
# Average loss at step 90000: 3.366944
# Nearest to is: was, has, are, seems, although, does, bullock, if,
# Nearest to than: disproportionately, no, slightly, spires, austere, template, races, elohim,
# Nearest to zero: eight, five, seven, six, nine, four, three, u,
# Nearest to war: wars, signed, gravis, kabul, embittered, nanotechnology, broadsheet, crossed,
# Nearest to an: delimitation, cordoba, wes, familial, another, petra, ile, cowboy,
# Nearest to he: she, it, they, there, who, officially, but, finally,
# Nearest to state: government, city, falcone, states, ethelbert, clog, ingredient, medal,
# Nearest to at: under, in, during, after, on, against, lawrence, summarizing,
# Nearest to the: its, their, his, a, this, any, unaided, your,
# Nearest to can: could, may, will, would, must, should, might, cannot,
# Nearest to as: servicemen, flannery, tsarevich, fief, advancements, offences, antiderivative, driscoll,
# Nearest to states: kingdom, nations, state, countries, approve, us, outlets, hertfordshire,
# Nearest to many: some, several, these, various, numerous, all, most, certain,
# Nearest to four: five, seven, three, eight, six, two, nine, zero,
# Nearest to not: still, now, we, touted, they, never, also, obviously,
# Nearest to UNK: richards, wolfgang, gast, et, swollen, le, http, berkeley,
# Average loss at step 92000: 3.400337
# Average loss at step 94000: 3.256042
# Average loss at step 96000: 3.361529
# Average loss at step 98000: 3.244325
# Average loss at step 100000: 3.357762
# Nearest to is: was, has, seems, became, refers, are, makes, does,
# Nearest to than: or, disproportionately, much, slightly, spires, elohim, template, dms,
# Nearest to zero: five, six, eight, four, seven, nine, three, two,
# Nearest to war: wars, kabul, signed, gravis, crossed, boating, mocks, coleco,
# Nearest to an: another, delimitation, sabbatical, familial, cordoba, heapsort, wes, pacification,
# Nearest to he: she, it, they, there, who, we, never, discreet,
# Nearest to state: government, city, states, medal, falcone, ethelbert, prat, community,
# Nearest to at: on, after, during, under, summarizing, near, klaip, nchen,
# Nearest to the: their, its, your, his, a, this, our, any,
# Nearest to can: may, could, will, would, should, must, cannot, might,
# Nearest to as: like, driscoll, including, dmu, became, longitudes, when, tz,
# Nearest to states: kingdom, state, nations, countries, us, capitalised, forces, cricketing,
# Nearest to many: some, several, these, various, numerous, all, few, those,
# Nearest to four: seven, six, five, eight, three, two, nine, zero,
# Nearest to not: never, still, now, they, partitioned, only, otherwise, also,
# Nearest to UNK: mahabharata, stadler, storyteller, von, et, solidification, dcc, killings,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
